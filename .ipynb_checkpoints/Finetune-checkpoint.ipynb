# %%
# pip install scipy

# %%
# %load_ext autoreload
# %autoreload 2
import torch
from training_utils import train_model, test
from models import BBandFChead

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from torchvision.models import resnet50, ResNet50_Weights
from torch import nn

resnet = resnet50(weights=ResNet50_Weights.DEFAULT)
# resnet = resnet50(pretrained=True, ) 
resnet.fc = nn.Identity() # removing pretrained last layer
resnet_linear = BBandFChead(resnet, hidden_dim=0, output_dim=101) # creating a model with frozen bb and only a linear eval head.
# Out:
# /home/me.docker/.conda/envs/torch-p37/lib/python3.7/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/jovyan/.conda/envs/torch-p37/lib/python3.7/site-packages/torchvision/image.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warn(f"Failed to load image Python extension: {e}")
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /home/me.docker/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 53.9MB/s]

# %%
from torch.utils.data import DataLoader
from caltech101 import load_caltech101

train_dataset, test_dataset = load_caltech101(data_path="/home/me.docker/work/data")
batch_size = 64
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=1)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, num_workers=1)
# Out:
# 6941 1736

# %%
train_model(resnet_linear, train_dataset=train_dataset, test_dataset=test_dataset, batch_size=16,
            lr=0.0001, epochs=20, samples_per_epoch=None, test_max_samples=None)
# Out:
# Epoch 1, Step 6941: Test (16.3s): Average loss: 0.3340, Accuracy: 1630/1736 (93.89%), TPR: 98.59%, TNR: 98.96%, TNR+TPR/2: 98.77%
# Epoch 2, Step 13882: Test (16.1s): Average loss: 0.3175, Accuracy: 1629/1736 (93.84%), TPR: 98.59%, TNR: 98.96%, TNR+TPR/2: 98.77%
# Epoch 3, Step 20823: Test (16.5s): Average loss: 0.3046, Accuracy: 1629/1736 (93.84%), TPR: 98.59%, TNR: 98.96%, TNR+TPR/2: 98.77%
# Epoch 4, Step 27764: Test (16.6s): Average loss: 0.2936, Accuracy: 1632/1736 (94.01%), TPR: 98.59%, TNR: 98.96%, TNR+TPR/2: 98.77%
# Epoch 5, Step 34705: Test (16.8s): Average loss: 0.2841, Accuracy: 1633/1736 (94.07%), TPR: 98.59%, TNR: 98.96%, TNR+TPR/2: 98.77%
# Epoch 6, Step 41646: Test (16.7s): Average loss: 0.2758, Accuracy: 1632/1736 (94.01%), TPR: 98.59%, TNR: 98.96%, TNR+TPR/2: 98.77%
# Epoch 7, Step 48587: Test (16.0s): Average loss: 0.2684, Accuracy: 1634/1736 (94.12%), TPR: 98.59%, TNR: 98.96%, TNR+TPR/2: 98.77%
# Epoch 8, Step 55528: Test (16.2s): Average loss: 0.2618, Accuracy: 1634/1736 (94.12%), TPR: 98.59%, TNR: 98.96%, TNR+TPR/2: 98.77%

# %%
from matplotlib import pyplot as plt
f, axes = plt.subplots(3,3, figsize=(15,15))
mult = len(train_dataset)//9
for i, ax in enumerate(axes.flatten()):
    img = train_dataset[i*mult][0].permute(1,2,0)
    ax.imshow(img)
    ax.title.set_text(train_dataset[i*mult][1])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img.min()
# Out:
# tensor(-2.1179)
