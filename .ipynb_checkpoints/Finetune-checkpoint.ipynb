# %%
# pip install scipy

# %%
# %load_ext autoreload
# %autoreload 2
import torch
from training_utils import train_model, test
from models import BBandFChead, FrozenResNetAndFinetune, FrozenResNetAndFinetuneGroups
from torchvision.models import resnet50, ResNet50_Weights
from torch import nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1k training samples

# %%
# 1/0 
# preventing all future cells from deleting the outputs

# %%
from torch.utils.data import DataLoader
from caltech101 import load_caltech101

train_dataset, test_dataset = load_caltech101(data_path="/home/me.docker/work/data", train_dataset_len=1000)
batch_size = 2
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=1)
# test_dataloader = DataLoader(test_dataset, batch_size=batch_size, num_workers=1)
# get one data batch:
for img, l in train_dataloader:
    break
img.shape
# Out:
# Files already downloaded and verified
# 1000 7677
# torch.Size([2, 3, 224, 224])

# %% [markdown]
# ## Fine tune resnet with intemediete layers:

# %%
resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
resnet.fc = nn.Identity()
side_net = FrozenResNetAndFinetune(resnet, num_classes=101).to(device)
fine_net_group = FrozenResNetAndFinetuneGroups(resnet, num_classes=101).to(device)

print(f'total res: {sum(p.numel() for p in resnet.parameters()):,d}')
print(f'total res: {sum(p.numel() for p in side_net.parameters()):,d}')
print(f'total res: {sum(p.numel() for p in fine_net_group.parameters()):,d}')

# %%
from models import FrozenResNetAndFinetune

train_dataset, test_dataset = load_caltech101(data_path="/home/me.docker/work/data")

for i in range(3):
    resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
    fine_tune_net = FrozenResNetAndFinetune(resnet, num_classes=101).to(device)
    _ = train_model(fine_tune_net, train_dataset=train_dataset, test_dataset=test_dataset, batch_size=16,
                lr=0.0001, epochs=10, samples_per_epoch=None, test_max_samples=None, silent=False, plot=True)
# Out:
# 6941 1736
# Best accuracy of 95.97 achieved at epoch 8loss: 0.1739, Accuracy: 1664/1736 (95.85%))
# Best accuracy of 95.97 achieved at epoch 6loss: 0.1772, Accuracy: 1660/1736 (95.62%))
# Best accuracy of 95.68 achieved at epoch 9loss: 0.1777, Accuracy: 1661/1736 (95.68%))

# %%
# with groups:
resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
fine_tune_net = FrozenResNetAndFinetune(resnet, num_classes=101).to(device)
_ = train_model(fine_tune_net, train_dataset=train_dataset, test_dataset=test_dataset, batch_size=16,
            lr=0.0001, epochs=10, samples_per_epoch=None, test_max_samples=None, silent=False, plot=True)
# Out:
# Test;  Epoch 10, Step 00069410 (16.7s)  : loss: 0.1911, Accuracy: 1651/1736 (95.10%))
# Best accuracy of 95.10 achieved at epoch 9

# %%
# with redu groups:
resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
fine_tune_net = FrozenResNetAndFinetune(resnet, num_classes=101, verbose=False).to(device)
_ = train_model(fine_tune_net, train_dataset=train_dataset, test_dataset=test_dataset, batch_size=16,
            lr=0.0001, epochs=10, samples_per_epoch=None, test_max_samples=None, silent=False, plot=True)
# Out:
# Test;  Epoch 5, Step 00034705 (16.6s)   : loss: 0.3251, Accuracy: 1621/1736 (93.38%)

# %%
resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
fine_tune_net = FrozenResNetAndFinetune(resnet, num_classes=101, finetune_shape=32).to(device)

# for f,r  in zip(list(fine_tune_net.fc.parameters()), list(resnet.fc.parameters())):
#     print(f.numel() - r.numel())
total_params = sum(p.numel() for p in fine_tune_net.parameters())
fine_tune_net.fc = nn.Identity()
no_fc = sum(p.numel() for p in fine_tune_net.parameters())
fine_tune_net.l4_layers = nn.Identity()
fine_tune_net.l4_conv = nn.Identity()
no_l4 = sum(p.numel() for p in fine_tune_net.parameters())
fine_tune_net.l3_layers = nn.Identity()
fine_tune_net.l3_conv = nn.Identity()
no_l3 = sum(p.numel() for p in fine_tune_net.parameters())
fine_tune_net.l2_layers = nn.Identity()
fine_tune_net.l2_conv = nn.Identity()

no_l2 = sum(p.numel() for p in fine_tune_net.parameters())
fine_tune_net.l1_layers = nn.Identity()
fine_tune_net.l1_conv = nn.Identity()
no_l1 = sum(p.numel() for p in fine_tune_net.parameters())
print(f'total my: {total_params:,d}')
print(f'total no_fc: {no_fc:,d} ({total_params-no_fc:,d})')
print(f'total no_l4: {no_l4:,d} ({no_fc - no_l4:,d})')
print(f'total no_l3: {no_l3:,d} ({no_l4 - no_l3:,d})')
print(f'total no_l2: {no_l2:,d} ({no_l3 - no_l2:,d})')
print(f'total no_l1: {no_l1:,d}')

resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
resnet.fc = nn.Linear(2048, 101)
print(f'total res: {sum(p.numel() for p in resnet.parameters()):,d}')
# Out:
# total my: 24,313,189
# total no_fc: 24,080,384 (232,805)
# total no_l4: 23,858,688 (221,696)
# total no_l3: 23,637,248 (221,440)
# total no_l2: 23,581,824 (55,424)
# total no_l1: 23,508,032
# total res: 23,714,981

# %%
sum(p.numel() for p in nn.Linear(2048, 101).parameters())
# Out:
# 206949

# %%
# validate shapes
# fine_tune_net.verbose = True
# img = img.to(device)
# bb_out = fine_tune_net(img)
# fine_tune_net.verbose = False

for i in range(3):
    resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
    resnet.fc = nn.Identity() # removing pretrained last layerS
    resnet_frozen = BBandFChead(resnet, hidden_dim=0, output_dim=101, train_bb=False) # creating a model with frozen bb and only a linear eval head.
    _ = train_model(resnet_frozen, train_dataset=train_dataset, test_dataset=test_dataset, batch_size=16,
                lr=0.0001, epochs=20, samples_per_epoch=None, test_max_samples=None, silent=False, plot=True)
# Out:
# Test;  Epoch 20, Step 00138820 (16.4s)  : loss: 0.2182, Accuracy: 1636/1736 (94.24%)
# Best accuracy of 94.24 achieved at epoch 19
# Test;  Epoch 20, Step 00138820 (16.6s)  : loss: 0.2189, Accuracy: 1639/1736 (94.41%)
# Best accuracy of 94.41 achieved at epoch 19
# Test;  Epoch 5, Step 00034705 (16.4s)   : loss: 0.4416, Accuracy: 1591/1736 (91.65%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_123/1229675469.py in <module>
#      10     resnet_frozen = BBandFChead(resnet, hidden_dim=0, output_dim=101, train_bb=False) # creating a model with frozen bb and only a linear eval head.
#      11     _ = train_model(resnet_frozen, train_dataset=train_dataset, test_dataset=test_dataset, batch_size=16,
# ---> 12                 lr=0.0001, epochs=20, samples_per_epoch=None, test_max_samples=None, silent=False, plot=True)
#      13
#      14
#
# /home/jovyan/finetune/training_utils.py in train_model(model, train_dataset, test_dataset, epochs, samples_per_epoch, test_max_samples, log_interval, batch_size, lr, silent, plot)
#     159         start = time.time()
#     160         train_loss, train_acc, _, _ = train_epoch(model, train_dataloader, optimizer=optimizer,
# --> 161                                                   max_samples=samples_per_epoch, log_interval=log_interval, epoch=e, silent=silent)
#     162         train_loss_list.append(train_loss)
#     163         train_acc_list.append(train_acc)
#
# /home/jovyan/finetune/training_utils.py in train_epoch(model, train_dataloader, optimizer, max_samples, epoch, log_interval, silent)
#     106     model.to(device)
#     107     samples_per_train_epoch = max_samples if max_samples is not None else len(train_dataloader)
# --> 108     for single_sample in train_dataloader:
#     109         data, target, sample_weight = get_imgs_and_labels(single_sample, device)
#     110         optimizer.zero_grad()
#
# ~/.conda/envs/torch-p37/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     679                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680                 self._reset()  # type: ignore[call-arg]
# --> 681             data = self._next_data()
#     682             self._num_yielded += 1
#     683             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.conda/envs/torch-p37/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1357
#    1358             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1359             idx, data = self._get_data()
#    1360             self._tasks_outstanding -= 1
#    1361             if self._dataset_kind == _DatasetKind.Iterable:
#
# ~/.conda/envs/torch-p37/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1323         else:
#    1324             while True:
# -> 1325                 success, data = self._try_get_data()
#    1326                 if success:
#    1327                     return data
#
# ~/.conda/envs/torch-p37/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1161         #   (bool: whether successfully get data, any: data if successful else None)
#    1162         try:
# -> 1163             data = self._data_queue.get(timeout=timeout)
#    1164             return (True, data)
#    1165         except Exception as e:
#
# ~/.conda/envs/torch-p37/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# ~/.conda/envs/torch-p37/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# ~/.conda/envs/torch-p37/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# ~/.conda/envs/torch-p37/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     919
#     920             while True:
# --> 921                 ready = selector.select(timeout)
#     922                 if ready:
#     923                     return [key.fileobj for (key, events) in ready]
#
# ~/.conda/envs/torch-p37/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
resnet.fc = nn.Identity() # removing pretrained last layer
resnet_linear = BBandFChead(resnet, hidden_dim=0, output_dim=101, train_bb=False) # creating a model with frozen bb and only a linear eval head.
train_model(resnet_linear, train_dataset=train_dataset, test_dataset=test_dataset, batch_size=16,
            lr=0.0001, epochs=5, samples_per_epoch=None, test_max_samples=None, plot=False)

reloded_resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
reloded_resnet.to(device)
print(f'Are BB weights same as pretrained model? - {torch.all(resnet_linear.bb_model.conv1.weight == reloded_resnet.conv1.weight)}')

resnet_linear.train_bb = True # unfreeze bb
train_model(resnet_linear, train_dataset=train_dataset, test_dataset=test_dataset, batch_size=16,
            lr=0.0001, epochs=5, samples_per_epoch=None, test_max_samples=None)

print(f'Are BB weights same as pretrained model? - {torch.all(resnet_linear.bb_model.conv1.weight == reloded_resnet.conv1.weight)}')
# Out:
# Test;  Epoch 5, Step 00034705 (16.5s)   : loss: 0.4470, Accuracy: 1594/1736 (91.82%)
# Best accuracy of 91.82 achieved at epoch 4
# Are BB weights same as pretrained model? - True
# Test;  Epoch 5, Step 00034705 (17.0s)   : loss: 0.1199, Accuracy: 1680/1736 (96.77%)
# Best accuracy of 96.77 achieved at epoch 4
# Are BB weights same as pretrained model? - False

# %% [markdown]
# ## linear eval on top of frozen ResNet50

# %%
1/0

# %%
resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
resnet.fc = nn.Identity() # removing pretrained last layerS
resnet_frozen = BBandFChead(resnet, hidden_dim=0, output_dim=101, train_bb=False) # creating a model with frozen bb and only a linear eval head.
train_model(resnet_frozen, train_dataset=train_dataset, test_dataset=test_dataset, batch_size=16,
            lr=0.0001, epochs=40, samples_per_epoch=None, test_max_samples=1000)

reloded_resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
reloded_resnet.to(device)
print(f'Are BB weights same as pretrained model? - {torch.all(resnet_frozen.bb_model.conv1.weight == reloded_resnet.conv1.weight)}')
# Out:
# Train; Epoch 1, Step 00001008           : loss: 0.2649, Accuracy: 130/1000 (13.00%)
# Test;  Epoch 1, Step 00001000 (2.7s)    : loss: 3.8697, Accuracy: 225/1008 (22.32%)
# Train; Epoch 2, Step 00002016           : loss: 0.2228, Accuracy: 259/1000 (25.90%)
# Test;  Epoch 2, Step 00002000 (2.7s)    : loss: 3.3956, Accuracy: 272/1008 (26.98%)
# Train; Epoch 3, Step 00003024           : loss: 0.1926, Accuracy: 308/1000 (30.80%)
# Test;  Epoch 3, Step 00003000 (2.6s)    : loss: 2.9935, Accuracy: 375/1008 (37.20%)
# Train; Epoch 4, Step 00004032           : loss: 0.1665, Accuracy: 438/1000 (43.80%)
# Test;  Epoch 4, Step 00004000 (2.6s)    : loss: 2.6590, Accuracy: 482/1008 (47.82%)
# Train; Epoch 5, Step 00005040           : loss: 0.1443, Accuracy: 556/1000 (55.60%)
# Test;  Epoch 5, Step 00005000 (2.6s)    : loss: 2.3797, Accuracy: 547/1008 (54.27%)
# Train; Epoch 6, Step 00006048           : loss: 0.1251, Accuracy: 684/1000 (68.40%)
# Test;  Epoch 6, Step 00006000 (2.6s)    : loss: 2.1448, Accuracy: 615/1008 (61.01%)
# Train; Epoch 7, Step 00007056           : loss: 0.1087, Accuracy: 787/1000 (78.70%)
# Test;  Epoch 7, Step 00007000 (2.6s)    : loss: 1.9463, Accuracy: 674/1008 (66.87%)
# Train; Epoch 8, Step 00008064           : loss: 0.0946, Accuracy: 858/1000 (85.80%)
# Test;  Epoch 8, Step 00008000 (2.5s)    : loss: 1.7780, Accuracy: 719/1008 (71.33%)
# Train; Epoch 9, Step 00009072           : loss: 0.0826, Accuracy: 901/1000 (90.10%)
# Test;  Epoch 1, Step 00006941 (17.0s)   : loss: 0.2070, Accuracy: 1626/1736 (93.66%)
# Train; Epoch 2, Step 00013888           : loss: 0.0028, Accuracy: 6885/6941 (99.19%)
# Test;  Epoch 2, Step 00013882 (16.4s)   : loss: 0.1773, Accuracy: 1657/1736 (95.45%)
# Train; Epoch 3, Step 00020832           : loss: 0.0009, Accuracy: 6926/6941 (99.78%)
# Test;  Epoch 3, Step 00020823 (16.9s)   : loss: 0.1275, Accuracy: 1671/1736 (96.26%)
# Train; Epoch 4, Step 00027776           : loss: 0.0004, Accuracy: 6932/6941 (99.87%)
# Test;  Epoch 4, Step 00027764 (16.9s)   : loss: 0.1327, Accuracy: 1673/1736 (96.37%)
# Train; Epoch 5, Step 00034720           : loss: 0.0003, Accuracy: 6934/6941 (99.90%)
# Test;  Epoch 5, Step 00034705 (16.8s)   : loss: 0.1270, Accuracy: 1673/1736 (96.37%)
# Are BB weights same as pretrained model? - False

# %% [markdown]
# ## Training a linear classifier on top of a frozen ResNet50

# %%
resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
resnet.fc = nn.Identity() # removing pretrained last layerS
resnet_frozen = BBandFChead(resnet, hidden_dim=0, output_dim=101, train_bb=False) # creating a model with frozen bb and only a linear eval head.
train_model(resnet_frozen, train_dataset=train_dataset, test_dataset=test_dataset, batch_size=16,
            lr=0.0001, epochs=20, samples_per_epoch=None, test_max_samples=None)

reloded_resnet = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
reloded_resnet.to(device)
print(f'Are BB weights same as pretrained model? - {torch.all(resnet_frozen.bb_model.conv1.weight == reloded_resnet.conv1.weight)}')
# Out:
# Train; Epoch 1, Step 00006944           : loss: 0.1892, Accuracy: 2628/6941 (37.86%)
# Test;  Epoch 1, Step 00006941 (16.7s)   : loss: 1.9699, Accuracy: 1180/1736 (67.97%)
# Train; Epoch 2, Step 00013888           : loss: 0.0971, Accuracy: 5372/6941 (77.40%)
# Test;  Epoch 2, Step 00013882 (16.7s)   : loss: 1.1148, Accuracy: 1462/1736 (84.22%)
# Train; Epoch 3, Step 00020832           : loss: 0.0597, Accuracy: 6187/6941 (89.14%)
# Test;  Epoch 3, Step 00020823 (16.7s)   : loss: 0.7495, Accuracy: 1558/1736 (89.75%)
# Train; Epoch 4, Step 00027776           : loss: 0.0415, Accuracy: 6429/6941 (92.62%)
# Test;  Epoch 4, Step 00027764 (17.0s)   : loss: 0.5702, Accuracy: 1584/1736 (91.24%)
# Train; Epoch 5, Step 00034720           : loss: 0.0314, Accuracy: 6559/6941 (94.50%)
# Test;  Epoch 5, Step 00034705 (16.9s)   : loss: 0.4697, Accuracy: 1593/1736 (91.76%)
# Train; Epoch 6, Step 00041664           : loss: 0.0251, Accuracy: 6623/6941 (95.42%)
# Test;  Epoch 6, Step 00041646 (16.6s)   : loss: 0.4071, Accuracy: 1607/1736 (92.57%)
# Train; Epoch 7, Step 00048608           : loss: 0.0208, Accuracy: 6670/6941 (96.10%)
# Test;  Epoch 7, Step 00048587 (16.6s)   : loss: 0.3648, Accuracy: 1614/1736 (92.97%)
